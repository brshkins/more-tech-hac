# %%
import pandas as pd
import numpy as np
import os
import requests
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.schema import Document
from langchain.docstore import InMemoryDocstore
import faiss
from typing import List
from langchain.embeddings.base import Embeddings
from tenacity import retry, stop_after_attempt, wait_random_exponential

# %%
data = pd.read_csv('KnowledgeBase.csv')
data.head()
# Out:
#      Топик            Подтопик  \
# 0  Главное  Приложение Мой МТС
# 1  Главное  Приложение Мой МТС
# 2  Главное  Приложение Мой МТС
# 3  Главное  Приложение Мой МТС
# 4  Главное  Приложение Мой МТС
#
#                                    Поисковой запрос  \
# 0     Как проверить последние пополнения и списания
# 1                          Как заказать детализацию
# 2                Как оставаться на связи при минусе
# 3           Как проверить баланс и пакеты по тарифу
# 4  Что делать, если остатки пакетов не показываются
#
#                                                Текст
# 0   1. Откройте Расходы\n\n\n2. По умолчанию отоб...
# 1  \nВ детализации есть полные данные о том, как ...
# 2  Есть несколько способов пользоваться номером п...
# 3  На главном экране, который открывается при вхо...
# 4  Вы не увидите остатки интернета, минут или СМС...

# %%
data.columns = ['topic', 'subtopic', 'query', 'text']
data.head()
# Out:
#      topic            subtopic  \
# 0  Главное  Приложение Мой МТС
# 1  Главное  Приложение Мой МТС
# 2  Главное  Приложение Мой МТС
# 3  Главное  Приложение Мой МТС
# 4  Главное  Приложение Мой МТС
#
#                                               query  \
# 0     Как проверить последние пополнения и списания
# 1                          Как заказать детализацию
# 2                Как оставаться на связи при минусе
# 3           Как проверить баланс и пакеты по тарифу
# 4  Что делать, если остатки пакетов не показываются
#
#                                                 text
# 0   1. Откройте Расходы\n\n\n2. По умолчанию отоб...
# 1  \nВ детализации есть полные данные о том, как ...
# 2  Есть несколько способов пользоваться номером п...
# 3  На главном экране, который открывается при вхо...
# 4  Вы не увидите остатки интернета, минут или СМС...

# %%
data = data.drop('text', axis=1)
data.head()
# Out:
#      topic            subtopic  \
# 0  Главное  Приложение Мой МТС
# 1  Главное  Приложение Мой МТС
# 2  Главное  Приложение Мой МТС
# 3  Главное  Приложение Мой МТС
# 4  Главное  Приложение Мой МТС
#
#                                               query
# 0     Как проверить последние пополнения и списания
# 1                          Как заказать детализацию
# 2                Как оставаться на связи при минусе
# 3           Как проверить баланс и пакеты по тарифу
# 4  Что делать, если остатки пакетов не показываются

# %%
data['class'] = data['topic'] + '-' + data['subtopic']
data.head()
# Out:
#      topic            subtopic  \
# 0  Главное  Приложение Мой МТС
# 1  Главное  Приложение Мой МТС
# 2  Главное  Приложение Мой МТС
# 3  Главное  Приложение Мой МТС
# 4  Главное  Приложение Мой МТС
#
#                                               query  \
# 0     Как проверить последние пополнения и списания
# 1                          Как заказать детализацию
# 2                Как оставаться на связи при минусе
# 3           Как проверить баланс и пакеты по тарифу
# 4  Что делать, если остатки пакетов не показываются
#
#                         class
# 0  Главное-Приложение Мой МТС
# 1  Главное-Приложение Мой МТС
# 2  Главное-Приложение Мой МТС
# 3  Главное-Приложение Мой МТС
# 4  Главное-Приложение Мой МТС

# %%
data['class'].unique()
# Out:
# array(['Главное Приложение Мой МТС', 'Главное Личный кабинет',
#        'Главное МТС ID', 'Главное МТС Premium', 'Главное МТС Cashback',
#        'Безопасность Защитник', 'Безопасность Membrana',
#        'Безопасность Мой поиск', 'Развлечения KION',
#        'Развлечения МТС Музыка', 'Развлечения МТС Live',
#        'Развлечения Строки', "Развлечения МТС GOOD'OK",
#        'Развлечения МТС Юрент', 'Развлечения Rushbe',
#        'Утилиты Вторая Память', 'Утилиты МТС Лончер', 'Финансы МТС Банк',
#        'Финансы МТС Деньги', 'Финансы МТС Все страховки',
#        'Финансы МТС Инвестиции', 'Детям и родителям МТС Лончер Junior',
#        'Детям и родителям МТС Junior', 'Детям и родителям Membrana Kids',
#        'Для дома МТС Умный дом', 'Для дома VDome',
#        'Другое Интернет-магазин', 'Другое МТС Тестирование',
#        'Другое Crowdloud'], dtype=object)

# %%
class MTS_Embeddings(Embeddings):
    def __init__(self, api_key: str):
        self.api_key = api_key
        self.api_url = "https://api.gpt.mws.ru/v1/embeddings"
        
    def embed_documents(self, texts: List[str]) -> List[List[float]]:
        return [self._get_embedding(text) for text in texts]
    
    def embed_query(self, text: str) -> List[float]:
        return self._get_embedding(text)
        
    @retry(wait=wait_random_exponential(min=20, max=50), stop=stop_after_attempt(200))
    def _get_embedding(self, text: str) -> List[float]:
        headers = {'Authorization': f'Bearer {self.api_key}'}
        data = {
            "model": "bge-m3",
            'input': text
            }
        try:
            response = requests.post(self.api_url, json=data, headers=headers)
            return response.json()['data'][0]['embedding']
        except Exception as e:
            print(e)
            print(response)
            return e

# %%
# Class to normalize embeddings for cosine similarity
class NormalizedEmbeddings(Embeddings):
    def __init__(self, embeddings: Embeddings):
        self.embeddings = embeddings

    def embed_documents(self, texts: List[str]) -> List[List[float]]:
        embeddings = self.embeddings.embed_documents(texts)
        return [list(np.array(emb) / np.linalg.norm(emb)) for emb in embeddings]

    def embed_query(self, text: str) -> List[float]:
        embedding = self.embeddings.embed_query(text)
        return list(np.array(embedding) / np.linalg.norm(embedding))

# %%
text_series = data['query']

# %%
api_key = os.getenv('API_KEY')
mts_embeddings = MTS_Embeddings(api_key=api_key)

# %%
normalized_embeddings = NormalizedEmbeddings(mts_embeddings)

# %%
docs = [Document(page_content=text, metadata={"series_index": idx}) 
        for idx, text in zip(text_series.index, text_series.tolist())]

# %%
embeddings = normalized_embeddings.embed_documents([doc.page_content for doc in docs])

# %%
dimension = len(embeddings[0])

# %%
index = faiss.IndexFlatIP(dimension)

# %%
index.add(np.array(embeddings))

# %%
docstore = InMemoryDocstore({str(i): doc for i, doc in enumerate(docs)})
index_to_docstore_id = {i: str(i) for i in range(len(docs))}

# %%
vector_store = FAISS(
    embedding_function=normalized_embeddings.embed_query,
    index=index,
    docstore=docstore,
    index_to_docstore_id=index_to_docstore_id
)
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
def retrieve_similar_entry(query: str):
    results = vector_store.similarity_search_with_score(query, k=1)
    if results:
        most_similar_doc, score = results[0]
        original_text = most_similar_doc.page_content
        confidence = score  # Cosine similarity (inner product of normalized vectors)
        original_index = most_similar_doc.metadata["series_index"]
        return {
            "original_text": original_text,
            "confidence": confidence,
        }
    return None

# %%
answer_dict = {key : answer for key, answer in zip(data['query'], data['class'])}
answer_dict
# Out:
# {'Как проверить последние пополнения и списания': 'Главное-Приложение Мой МТС',
#  'Как заказать детализацию': 'Главное-Приложение Мой МТС',
#  'Как оставаться на связи при минусе': 'Главное-Приложение Мой МТС',
#  'Как проверить баланс и пакеты по тарифу': 'Главное-Приложение Мой МТС',
#  'Что делать, если остатки пакетов не показываются': 'Главное-Приложение Мой МТС',
#  'Что такое прогноз списаний и как его посмотреть': 'Главное-Приложение Мой МТС',
#  'Почему прогноз может измениться': 'Главное-Приложение Мой МТС',
#  'Почему даты списаний могут меняться': 'Главное-Приложение Мой МТС',
#  'Как узнать, сколько осталось интернета': 'Главное-Приложение Мой МТС',
#  'Что делать, если интернет заканчивается': 'Главное-Приложение Мой МТС',
#  'Дополнительные пакеты интернета — автопродление': 'Главное-Приложение Мой МТС',
#  'Как узнать подробности о своём тарифе': 'Главное-Приложение Мой МТС',
#  'Как настроить тариф': 'Главное-Приложение Мой МТС',
#  'Как обновить пакеты по тарифу': 'Главное-Приложение Мой МТС',
#  'Как изменить свой тариф': 'Главное-Приложение Мой МТС',
#  'Добровольная блокировка': 'Главное-Приложение Мой МТС',
#  'Как посмотреть подключённые услуги': 'Главное-Приложение Мой МТС',
#  'Как отключить услуги': 'Главное-Приложение Мой МТС',
#  'Зачем менять SIM-карту': 'Главное-Приложение Мой МТС',
#  'Как заменить SIM-карту': 'Главное-Приложение Мой МТС',
#  'Как заказать доставку SIM-карты для замены': 'Главное-Приложение Мой МТС',
#  'Как заменить SIM-карту на eSIM': 'Главное-Приложение Мой МТС',
#  'Как сменить номер без оформления новой SIM-карты': 'Главное-Приложение Мой МТС',
#  'Как переоформить номер на другого человека': 'Главное-Приложение Мой МТС',
#  'Как привязать банковскую карту': 'Развлечения-Строки',
#  'Как удалить банковскую карту': 'Главное-Приложение Мой МТС',
#  'Почему в приложении есть моя банковская карта, хотя я её не привязывал': 'Главное-Приложение Мой МТС',
#  'Как следить за балансом близких людей': 'Главное-Приложение Мой МТС',
#  'Группа для близких': 'Главное-Приложение Мой МТС',
#  'Группа «Все вместе» и «Все вместе+»': 'Главное-Приложение Мой МТС',
#  'Услуга «Общий пакет»': 'Главное-Приложение Мой МТС',
#  'Информация в виджетах': 'Главное-Приложение Мой МТС',
#  'Как подключить': 'Главное-Приложение Мой МТС',
#  'Чем отличаются виджеты Мой МТС': 'Главное-Приложение Мой МТС',
#  'Переключение между аккаунтами на виджетах для iOS': 'Главное-Приложение Мой МТС',
#  'Почему виджет не обновляется или отображается как «!»': 'Главное-Приложение Мой МТС',
#  'Чем полезен виджет Мой Поиск': 'Главное-Приложение Мой МТС',
#  'На каких смартфонах он работает': 'Главное-Приложение Мой МТС',
#  'Кто может пользоваться Мой Поиск в Мой МТС': 'Главное-Приложение Мой МТС',
#  'Где находится виджет Мой Поиск в Мой МТС': 'Главное-Приложение Мой МТС',
#  'Установка связей между аккаунтами': 'Главное-Приложение Мой МТС',
#  'Почему я получаю уведомления, которые затем пропадают': 'Главное-Приложение Мой МТС',
#  'Как войти в Личный кабинет без пароля': 'Главное-Личный кабинет',
#  'Как зайти в Личный кабинет с планшета': 'Главное-Личный кабинет',
#  'Что делать, если вы забыли пароль': 'Главное-Личный кабинет',
#  'Как поменять пароль в Личном кабинете': 'Главное-Личный кабинет',
#  'Как настроить вход в Личный кабинет по постоянному паролю без СМС': 'Главное-Личный кабинет',
#  'Могу ли я пользоваться Личным кабинетом при нулевом или отрицательном балансе': 'Главное-Личный кабинет',
#  'Как подключить обещанный платёж в Личном кабинете': 'Главное-Личный кабинет',
#  'Как проверить зачисления платежей в Личном кабинете': 'Главное-Личный кабинет',
#  'Как узнать недавние расходы': 'Главное-Личный кабинет',
#  'Как заказать детализацию расходов': 'Главное-Личный кабинет',
#  'Как узнать условия своего тарифа в Личном кабинете': 'Главное-Личный кабинет',
#  'Как изменить тариф в Личном кабинете': 'Главное-Личный кабинет',
#  'Как проверить, есть ли у меня платные услуги': 'Главное-Личный кабинет',
#  'Как подключить или отключить услугу в Личном кабинете': 'Главное-Личный кабинет',
#  'Как привязать к своему Личному кабинету дополнительный номер': 'Главное-Личный кабинет',
#  'Как удалить из Личного кабинета ранее привязанный номер': 'Главное-Личный кабинет',
#  'Как посмотреть все оформленные на меня номера': 'Главное-Личный кабинет',
#  'Как включить переадресацию вызовов в Личном кабинете': 'Главное-Личный кабинет',
#  'Сколько стоит переадресация вызовов': 'Главное-Личный кабинет',
#  'Что такое МТС ID и для чего он нужен': 'Главное-МТС ID',
#  'Как настроить способ входа в МТС ID по СМС или паролю': 'Главное-МТС ID',
#  'Как установить или изменить пароль для входа в МТС ID': 'Главное-МТС ID',
#  'Как добавить дополнительные контакты для входа в сервисы МТС': 'Главное-МТС ID',
#  'Как изменить основной номер для входа в МТС ID': 'Главное-МТС ID',
#  'Зачем подтверждать персональные данные': 'Главное-МТС ID',
#  'Как подтвердить или обновить данные через Госуслуги': 'Главное-МТС ID',
#  'Как подтвердить или обновить данные по фото паспорта': 'Главное-МТС ID',
#  'Как подтвердить или изменить данные через T-Банк': 'Главное-МТС ID',
#  'Как подтвердить или изменить данные с помощью Alfa ID': 'Главное-МТС ID',
#  'Как подтвердить или изменить данные с помощью Сбер ID': 'Главное-МТС ID',
#  'Что делать, если не получилось подтвердить или изменить персональные данные': 'Главное-МТС ID',
#  'Что такое МТС Pay и для чего он нужен': 'Главное-МТС ID',
#  'Как привязать банковскую карту для оплаты в МТС Pay': 'Главное-МТС ID',
#  'Как удалить банковскую карту из МТС Pay': 'Главное-МТС ID',
#  'Почему в МТС Pay есть моя банковская карта, хотя я её не привязывал': 'Главное-МТС ID',
#  'Что делать, если забыл пароль для входа в МТС ID': 'Главное-МТС ID',
#  'Что делать, если на основной номер не приходит СМС с кодом для входа в МТС ID': 'Главное-МТС ID',
#  'Что делать, если на резервный номер не приходит СМС с кодом для входа в МТС ID': 'Главное-МТС ID',
#  'Что делать, если код для входа в МТС ID не приходит на email': 'Главное-МТС ID',
#  'Что делать, если аккаунт МТС ID временно заблокирован': 'Главное-МТС ID',
#  'Почему при входе в МТС ID порой нужно вводить символы с картинки': 'Главное-МТС ID',
#  'Что такое МТС Premium и какие есть подписки': 'Главное-МТС Premium',
#  'Как активировать привилегии от МТС Premium': 'Главное-МТС Premium',
#  'Кому доступна подписка МТС Premium': 'Главное-МТС Premium',
#  'Где доступна подписка МТС Premium': 'Главное-МТС Premium',
#  'Почему мне больше недоступны привилегии МТС Premium': 'Главное-МТС Premium',
#  'Как подключить подписку МТС Premium': 'Главное-МТС Premium',
#  'Как подключить подписку по промокоду': 'Главное-МТС Premium',
#  'Почему не получается подключить подписку МТС Premium по промокоду': 'Главное-МТС Premium',
#  'Как отключить подписку МТС Premium': 'Главное-МТС Premium',
#  'Как добавить участников в МТС Premium': 'Главное-МТС Premium',
#  'Почему не получается добавить участника в подписку МТС Premium': 'Главное-МТС Premium',
#  'Как удалить участников из МТС Premium': 'Главное-МТС Premium',
#  'Пакет интернета по подписке МТС Premium': 'Главное-МТС Premium',
#  'Суммируется ли интернет от МТС Premium с трафиком по тарифу': 'Главное-МТС Premium',
#  'Как подключить интернет от МТС Premium': 'Главное-МТС Premium',
#  'Почему по подписке МТС Premium подключилось 5 ГБ интернета, а не 50 ГБ': 'Главное-МТС Premium',
#  'Как проверить остаток интернета по подписке МТС Premium': 'Главное-МТС Premium',
#  'Можно ли раздавать интернет из пакета от МТС Premium': 'Главное-МТС Premium',
#  'Могут ли клиенты других операторов пользоваться интернет-пакетом от МТС Premium': 'Главное-МТС Premium',
#  'Как будет работать интернет от МТС Premium, если у вас безлимитный интернет по тарифу': 'Главное-МТС Premium',
#  'Как продлить интернет, если трафик от МТС Premium закончился': 'Главное-МТС Premium',
#  'Карта МТС Банка с МТС Premium': 'Главное-МТС Premium',
#  'Бонусы от МТС Premium при аренде машины в BelkaCar': 'Главное-МТС Premium',
#  'Как получить 30 дней подписки OZON Premium бесплатно': 'Главное-МТС Premium',
#  'МТС Premium и МТС Cashback объединились. Что изменилось для участников программы': 'Главное-МТС Cashback',
#  'Кто и как может стать участником программы МТС Cashback': 'Главное-МТС Cashback',
#  'Сколько стоит участие в программе МТС Cashback': 'Главное-МТС Cashback',
#  'С каким тарифом нельзя участвовать в программе МТС Cashback': 'Главное-МТС Cashback',
#  'Как выйти из программы МТС Cashback и что будет с кешбэком': 'Главное-МТС Cashback',
#  'Можно ли сменить владельца номера и сохранить свой кешбэк': 'Главное-МТС Cashback',
#  'Что такое кешбэк в МТС и как его получить': 'Главное-МТС Cashback',
#  'Правила начисления кешбэка': 'Главное-МТС Cashback',
#  'Как узнать о начислении кешбэка': 'Главное-МТС Cashback',
#  'Как узнать, сколько кешбэка на балансе': 'Главное-МТС Cashback',
#  'Кешбэк не начислен. Какие могут быть причины': 'Главное-МТС Cashback',
#  'Где проверить накопленный кешбэк': 'Главное-МТС Cashback',
#  'На что можно потратить кешбэк': 'Главное-МТС Cashback',
#  'Как пополнить баланс кешбэком': 'Главное-МТС Cashback',
#  'Как расходуется кешбэк на услуги связи': 'Главное-МТС Cashback',
#  'Почему я не могу вывести кешбэк': 'Главное-МТС Cashback',
#  'Сколько действует и когда сгорает накопленный кешбэк': 'Главное-МТС Cashback',
#  'Сгорает ли кешбэк, не израсходованный в текущем месяце на услуги связи': 'Главное-МТС Cashback',
#  'Как понять, что я участник МТС Premium': 'Главное-МТС Cashback',
#  'Сколько можно получить кешбэка с подпиской МТС Premium': 'Главное-МТС Cashback',
#  'Как перевести кешбэк между участникам подписки МТС Premium': 'Главное-МТС Cashback',
#  'Как получить кешбэк за покупки в интернет-магазине МТС и в салонах экосистемы МТС': 'Главное-МТС Cashback',
#  'Когда и сколько кешбэка можно получить за покупку': 'Главное-МТС Cashback',
#  'Как потратить кешбэк в салоне экосистемы МТС': 'Главное-МТС Cashback',
#  'Как потратить кешбэк на покупку в интернет-магазине МТС': 'Другое-Интернет-магазин',
#  'Как посмотреть историю начисления и списания кешбэка': 'Главное-МТС Cashback',
#  'Почему в истории операции нет кэшбэка за подтверждённые покупки': 'Главное-МТС Cashback',
#  'Что означают статусы покупок в истории кешбэка': 'Главное-МТС Cashback',
#  'Почему размер доступного кешбэка отрицательный': 'Главное-МТС Cashback',
#  'Как настроить автоплатёж кешбэка на пополнение баланса номера МТС': 'Главное-МТС Cashback',
#  'На какие номера можно установить автоплатёж кешбэком': 'Главное-МТС Cashback',
#  'Когда списывается кешбэк на автоплатёж': 'Главное-МТС Cashback',
#  'Есть ли лимиты для автоплатежей кешбэком': 'Главное-МТС Cashback',
#  'Как удалить автоплатёж кешбэка': 'Главное-МТС Cashback',
#  'Какой кешбэк по карте': 'Главное-МТС Cashback',
#  'Какие MCC у повышенных категорий при оплате картой МТС CASHBACK': 'Главное-МТС Cashback',
#  'Сколько кешбэка можно получить за покупки по карте МТС CASHBACK': 'Главное-МТС Cashback',
#  'Когда кешбэк за оплату картой МТС CASHBACK не начисляется': 'Главное-МТС Cashback',
#  'Когда придёт кешбэк за покупки по карте МТС CASHBACK': 'Главное-МТС Cashback',
#  'Зачем отключать блокировщик рекламы': 'Главное-МТС Cashback',
#  'Как отключить блокировщик рекламы': 'Главное-МТС Cashback',
#  'Чем полезен «Защитник»': 'Безопасность-Защитник',
#  'Кому доступен «Защитник»': 'Безопасность-Защитник',
#  'Как узнать уровень безопасности': 'Безопасность-Защитник',
#  'Как сообщить о спам-звонке': 'Безопасность-Защитник',
#  'Как проверить номер на спам или мошенничество': 'Безопасность-Защитник',
#  'Почему пропал виджет «Защитник»': 'Безопасность-Защитник',
#  'Как подключить «Защитник»': 'Безопасность-Защитник',
#  'Как разблокировать нужный звонок': 'Безопасность-Защитник',
#  'Как узнать, какие вызовы заблокировал «Защитник»': 'Безопасность-Защитник',
#  'Как настроить правила блокировки звонков': 'Безопасность-Защитник',
#  'Как настроить СМС-уведомления о заблокированных звонках': 'Безопасность-Защитник',
#  'Как отключить «Защитник»': 'Безопасность-Защитник',
#  'Как включить определитель номера': 'Безопасность-Защитник',
#  'Как отключить определитель номера': 'Безопасность-Защитник',
#  'Что делать, если не получается подключить определитель номера': 'Безопасность-Защитник',
#  'Как включить отслеживание утечек личных данных': 'Безопасность-Защитник',
#  'Как отслеживать утечки данных': 'Безопасность-Membrana',
#  'Как отключить отслеживание утечек': 'Безопасность-Защитник',
#  'Как подключить «Безопасный звонок»': 'Безопасность-Защитник',
#  'Как отключить «Безопасный звонок»': 'Безопасность-Защитник',
#  'Как подключить «Защитник+»': 'Безопасность-Защитник',
#  'Как отключить «Защитник+»': 'Безопасность-Защитник',
#  'Что такое Membrana': 'Безопасность-Membrana',
#  'Как защитить аккаунт Membrana': 'Безопасность-Membrana',
#  'Как подключить безлимитный интернет на тарифе Membrana': 'Безопасность-Membrana',
#  'Как подключить тариф Membrana': 'Безопасность-Membrana',
#  'Как подключить услугу Membrana': 'Безопасность-Membrana',
#  'Как управлять звонками в Membrana': 'Безопасность-Membrana',
#  'Как найти расшифровку звонков, на которые ответил ИИ-секретарь': 'Безопасность-Membrana',
#  'Как включить или выключить умный СМС-фильтр': 'Безопасность-Membrana',
#  'Как настроить переадресацию в Membrana': 'Безопасность-Membrana',
#  'Как пользоваться Безопасной сетью': 'Безопасность-Membrana',
#  'Как заблокировать подозрительные сайты и рекламу в интернете': 'Безопасность-Membrana',
#  'Что такое номера для разных случаев и как ими управлять': 'Безопасность-Membrana',
#  'Как оплачивать игры и сервисы в Membrana': 'Безопасность-Membrana',
#  'Что такое Мой поиск': 'Безопасность-Мой поиск',
#  'Кому доступно': 'Безопасность-Мой поиск',
#  'Где работает сервис': 'Безопасность-Мой поиск',
#  'Как начать пользоваться сервисом': 'Безопасность-Мой поиск',
#  'На каких устройствах работает приложение': 'Безопасность-Мой поиск',
#  'Как добавить контакт': 'Безопасность-Мой поиск',
#  'За мной наблюдают. Как запретить': 'Безопасность-Мой поиск',
#  'Какие бывают подписки': 'Безопасность-Мой поиск',
#  'Как отключить подписку': 'Безопасность-Мой поиск',
#  'Возможности родительского контроля': 'Безопасность-Мой поиск',
#  'Активация родительского контроля': 'Безопасность-Мой поиск',
#  'Почему не отображаются параметры смартфона ребенка': 'Безопасность-Мой поиск',
#  'Как запретить наблюдение, если вы под родительским контролем': 'Безопасность-Мой поиск',
#  'Геозона и уведомления о перемещениях': 'Безопасность-Мой поиск',
#  'Как определяется местоположение': 'Безопасность-Мой поиск',
#  'Как увеличить точность определения местоположения': 'Безопасность-Мой поиск',
#  'Как узнать местоположение, если нет интернета': 'Безопасность-Мой поиск',
#  'Почему два контакта находятся рядом, а Мой Поиск определяет их в разных местах': 'Безопасность-Мой поиск',
#  'Какие умные устройства можно отслеживать': 'Безопасность-Мой поиск',
#  'Как активировать устройство и начать наблюдение': 'Безопасность-Мой поиск',
#  'Возможные ошибки при активации устройства': 'Безопасность-Мой поиск',
#  'Удаление устройства': 'Безопасность-Мой поиск',
#  'Что такое KION': 'Развлечения-KION',
#  'На каких устройствах работает KION': 'Развлечения-KION',
#  'Как привязать несколько устройств к аккаунту': 'Развлечения-KION',
#  'Трачу ли я интернет, когда смотрю KION': 'Развлечения-KION',
#  'Как не расходовать интернет на просмотр KION': 'Развлечения-KION',
#  'Как подключить подписку KION': 'Развлечения-KION',
#  'Как активировать промокод в KION': 'Развлечения-KION',
#  'Как отключить подписку KION': 'Развлечения-KION',
#  'Как вернуть деньги за неиспользованный период по подписке KION': 'Развлечения-KION',
#  'Почему при входе в приложение нужно выбрать профиль': 'Развлечения-KION',
#  'Как создать дополнительный профиль в KION': 'Развлечения-KION',
#  'Сколько профилей можно создать': 'Развлечения-KION',
#  'Как отключить выбор профиля при входе в KION': 'Развлечения-KION',
#  'Как настроить родительский контроль в KION': 'Развлечения-KION',
#  'Как удалить профиль в KION': 'Развлечения-KION',
#  'Почему при входе в приложение нужно вводить ПИН-код': 'Развлечения-KION',
#  'Как убрать запрос ПИН-кода при входе в KION': 'Развлечения-KION',
#  'Как изменить ПИН-код в KION': 'Развлечения-KION',
#  'Что делать, если я не знаю свой ПИН-код от KION': 'Развлечения-KION',
#  'В SMS пришёл шестизначный код для KION, а ввести можно только четыре цифры': 'Развлечения-KION',
#  'Что делать, если превышен лимит попыток сброса ПИН-кода в KION': 'Развлечения-KION',
#  'Гарантия и сервисное обслуживание приставок KION': 'Развлечения-KION',
#  'О сервисе': 'Развлечения-МТС Музыка',
#  'Как начать пользоваться МТС Музыкой': 'Развлечения-МТС Музыка',
#  'Где и кому доступен сервис': 'Развлечения-МТС Музыка',
#  'Что мне доступно без подписки МТС Музыка': 'Развлечения-МТС Музыка',
#  'Преимущества подписки МТС Музыка': 'Развлечения-МТС Музыка',
#  'Какие есть подписки на МТС Музыку': 'Развлечения-МТС Музыка',
#  'Бесплатный пробный период в МТС Музыке': 'Развлечения-МТС Музыка',
#  'Как оплачивается подписка МТС Музыка': 'Развлечения-МТС Музыка',
#  'Подписка МТС Музыка оплачена, но не работает': 'Развлечения-МТС Музыка',
#  'Как отключить подписку на МТС Музыку': 'Развлечения-МТС Музыка',
#  'Как я могу перейти с посуточной подписки МТС Музыка на ежемесячную': 'Развлечения-МТС Музыка',
#  'Что делать, если при подключении подписки МТС Музыка возникла ошибка': 'Развлечения-МТС Музыка',
#  'Как активировать промокод на подписку МТС Музыка': 'Развлечения-МТС Музыка',
#  'Что будет, если активировать промокод на МТС Музыку во время бесплатного периода': 'Развлечения-МТС Музыка',
#  'Что происходит, когда действие промокода заканчивается': 'Развлечения-МТС Музыка',
#  'Ошибки при активации промокодов на подписку МТС Музыка': 'Развлечения-МТС Музыка',
#  'Как создать плейлист': 'Развлечения-МТС Музыка',
#  'Как перенести плейлист': 'Развлечения-МТС Музыка',
#  'Как поделиться плейлистом': 'Развлечения-МТС Музыка',
#  'Что делать, если прерываются треки': 'Развлечения-МТС Музыка',
#  'Что делать, если пропала музыка': 'Развлечения-МТС Музыка',
#  'Что делать, если после блокировки экрана iPhone музыка прерывается': 'Развлечения-МТС Музыка',
#  'Сколько устройств можно подключить к своему профилю': 'Развлечения-МТС Музыка',
#  'Как выйти из аккаунта МТС Музыки': 'Развлечения-МТС Музыка',
#  'Почему я не вижу МТС Музыку в списке приложений Android Auto': 'Развлечения-МТС Музыка',
#  'Как расходуется трафик при прослушивании треков': 'Развлечения-МТС Музыка',
#  'Технические характеристики МТС Музыки': 'Развлечения-МТС Музыка',
#  'Настройка работы в фоновом режиме на Samsung': 'Развлечения-МТС Музыка',
#  'Настройка работы в фоновом режиме на Xiaomi': 'Развлечения-МТС Музыка',
#  'Настройка работы в фоновом режиме на OPPO, Realme, Vivo': 'Развлечения-МТС Музыка',
#  'Настройка работы в фоновом режиме на Huawei, Honor': 'Развлечения-МТС Музыка',
#  'Какие условия акции МТС Музыка для абонентов МТС': 'Развлечения-МТС Музыка',
#  'На каких тарифах доступна акция МТС Музыка для абонентов МТС': 'Развлечения-МТС Музыка',
#  'Как получить полный доступ к музыке по акции МТС Музыка для абонентов МТС': 'Развлечения-МТС Музыка',
#  'Если у меня уже подключена платная подписка на МТС Музыку': 'Развлечения-МТС Музыка',
#  'Как пользоваться МТС Музыкой, если тариф не входит в условия акции': 'Развлечения-МТС Музыка',
#  'Сколько нужно платить за подписку в рамках акции МТС Музыка для абонентов МТС': 'Развлечения-МТС Музыка',
#  'Подхожу под условия акции, но подписка не подключилась': 'Развлечения-МТС Музыка',
#  'Сколько будет действовать подписка по акции': 'Развлечения-МТС Музыка',
#  'Что будет с подпиской, когда акция закончится': 'Развлечения-МТС Музыка',
#  'Что такое МТС Live': 'Развлечения-МТС Live',
#  'Есть ли наценка на билеты': 'Развлечения-МТС Live',
#  'Мне нет 18 лет, могу ли я пойти на мероприятие без взрослых': 'Развлечения-МТС Live',
#  'Как удалить аккаунт в приложении МТС Live': 'Развлечения-МТС Live',
#  'Как купить билет': 'Развлечения-МТС Live',
#  'Какие документы нужны для посещения театров Москвы и как переоформить билет': 'Развлечения-МТС Live',
#  'Как оплатить билет Пушкинской картой': 'Развлечения-МТС Live',
#  'Где найти купленные билеты': 'Развлечения-МТС Live',
#  'Как пользоваться электронным билетом': 'Развлечения-МТС Live',
#  'Что делать, если билет не пришёл на почту': 'Развлечения-МТС Live',
#  'Как вернуть билет, если не получается пойти на мероприятие': 'Развлечения-МТС Live',
#  'Что делать, если мероприятие отменили': 'Развлечения-МТС Live',
#  'Что делать, если мероприятие перенесли': 'Развлечения-МТС Live',
#  'Что такое подарочная карта': 'Развлечения-МТС Live',
#  'Как купить подарочную карту МТС Live': 'Развлечения-МТС Live',
#  'Как использовать подарочную карту МТС Live': 'Развлечения-МТС Live',
#  'Как проверить баланс и срок действия подарочной карты': 'Развлечения-МТС Live',
#  'Как вернуть подарочную карту': 'Развлечения-МТС Live',
#  'Как получить кешбэк в МТС Live': 'Развлечения-МТС Live',
#  'Как списать кешбэк на покупку билетов в МТС Live': 'Развлечения-МТС Live',
#  'Что делать, если после покупки билетов кешбэк не пришёл или пришёл не весь': 'Развлечения-МТС Live',
#  'Что делать, если не получается списать кешбэк в МТС Live': 'Развлечения-МТС Live',
#  'Как продавать билеты на своё мероприятие на сайте МТС Live': 'Развлечения-МТС Live',
#  'Изменения в сервисе Строки с 17 апреля 2025': 'Развлечения-Строки',
#  'Что такое Строки': 'Развлечения-Строки',
#  'Как пользоваться Строками': 'Развлечения-Строки',
#  'Трачу ли я интернет, когда использую Строки': 'Развлечения-Строки',
#  'Как работает пробный период': 'Развлечения-Строки',
#  'Сколько стоит и что включает в себя подписка Строки': 'Развлечения-Строки',
#  'Что даёт подписка МТС Premium в сервисе Строки': 'Развлечения-Строки',
#  'Как оформить подписку': 'Развлечения-Строки',
#  'Как отменить подписку в Строках': 'Развлечения-Строки',
#  'Что делать, если подписка не продлилась': 'Развлечения-Строки',
#  'Книга была у меня в подписке, а теперь её нет. Почему': 'Развлечения-Строки',
#  'Что произойдёт с моими книгами, если я отменю подписку': 'Развлечения-Строки',
#  'Активация промокодов в сервисе': 'Развлечения-Строки',
#  'Ошибки при активации промокода': 'Развлечения-Строки',
#  'Как купить книгу': 'Развлечения-Строки',
#  'Где найти мои купленные книги': 'Развлечения-Строки',
#  'Перешёл к другому оператору, а купленные книги пропали': 'Развлечения-Строки',
#  'Как продолжить читать книги на другом устройстве': 'Развлечения-Строки',
#  'Можно ли скачать файлы на телефон или компьютер': 'Развлечения-Строки',
#  'Как очистить память устройства': 'Развлечения-Строки',
#  'Как добавить книгу в избранное': 'Развлечения-Строки',
#  'Как удалить книгу из избранного': 'Развлечения-Строки',
#  'Можно ли скачать книги на устройство, а не в приложение': 'Развлечения-Строки',
#  'Как читать без интернета': 'Развлечения-Строки',
#  'Как читать книги без подписки': 'Развлечения-Строки',
#  'Как изменить шрифт, яркость или цвет фона': 'Развлечения-Строки',
#  'Могу ли я читать на сайте с компьютера': 'Развлечения-Строки',
#  "Что такое GOOD'OK": "Развлечения-МТС GOOD'OK",
#  'Сколько стоит': "Развлечения-МТС GOOD'OK",
#  "Как подключить GOOD'OK": "Развлечения-МТС GOOD'OK",
#  "Как отключить GOOD'OK": "Развлечения-МТС GOOD'OK",
#  'Подарок при подключении мелодии': "Развлечения-МТС GOOD'OK",
#  'Как загрузить свою мелодию вместо гудков': "Развлечения-МТС GOOD'OK",
#  'Как настроить проигрывание': "Развлечения-МТС GOOD'OK",
#  'Что можно установить вместо гудков': "Развлечения-МТС GOOD'OK",
#  'Как подарить мелодию': "Развлечения-МТС GOOD'OK",
#  'Почему на моём новом номере подключена услуга GOOD’OK': "Развлечения-МТС GOOD'OK",
#  'Что такое «Музыкальная шкатулка»': "Развлечения-МТС GOOD'OK",
#  'Какие особенности у услуги GOOD’OK': "Развлечения-МТС GOOD'OK",
#  'Как удалить мелодию': "Развлечения-МТС GOOD'OK",
#  'Что такое МТС Юрент': 'Развлечения-МТС Юрент',
#  'Какие есть ограничения в использовании самоката': 'Развлечения-МТС Юрент',
#  'Правила дорожного движения на электросамокатах': 'Развлечения-МТС Юрент',
#  'Когда начинается и заканчивается сезон самокатов': 'Развлечения-МТС Юрент',
#  'Какие могут быть штрафы при поездках на самокатах МТС Юрент': 'Развлечения-МТС Юрент',
#  'Как начать поездку': 'Развлечения-МТС Юрент',
#  'Как арендовать несколько самокатов или велосипедов на один аккаунт': 'Развлечения-МТС Юрент',
#  'Как ездить на электровелосипеде': 'Развлечения-МТС Юрент',
#  'Как отмечена территория использования': 'Развлечения-МТС Юрент',
#  'Как работает режим ожидания': 'Развлечения-МТС Юрент',
#  'Как завершить поездку': 'Развлечения-МТС Юрент',
#  'Зачем подтверждать данные в Mos ID при аренде самоката или велосипеда в Москве': 'Развлечения-МТС Юрент',
#  'Кому нужно подтверждать аккаунт в Mos ID при аренде самокатов и велосипедов в МТС Юрент': 'Развлечения-МТС Юрент',
#  'Как связать аккаунт МТС Юрент с Mos ID': 'Развлечения-МТС Юрент',
#  'Как определяется стоимость аренды': 'Развлечения-МТС Юрент',
#  'Тарифы на аренду электросамокатов': 'Развлечения-МТС Юрент',
#  'Как работает страхование во время поездки': 'Развлечения-МТС Юрент',
#  'Как включить или отключить полную страховку': 'Развлечения-МТС Юрент',
#  'Что делать, если произошёл страховой случай': 'Развлечения-МТС Юрент',
#  'Что делать, если произошло ДТП с самокатом или велосипедом': 'Развлечения-МТС Юрент',
#  'Что делать, если вы увидели правонарушение на самокате или велосипеде': 'Развлечения-МТС Юрент',
#  'Как привязать карту или другой способ оплаты в МТС Юрент': 'Развлечения-МТС Юрент',
#  'Что такое кошелёк в МТС Юрент и как оплатить поездку бонусами': 'Развлечения-МТС Юрент',
#  'Что такое старт на самокате или велосипеде, списались деньги в начале поездки': 'Развлечения-МТС Юрент',
#  'Что такое залог': 'Развлечения-МТС Юрент',
#  'Как удалить карту в приложении МТС Юрент': 'Развлечения-МТС Юрент',
#  'Что делать, если не открывается замок на велосипеде после режима ожидания': 'Развлечения-МТС Юрент',
#  'Что делать, если самокат сломался во время поездки': 'Развлечения-МТС Юрент',
#  'Если самокат сел, а я ещё не нахожусь на парковке': 'Развлечения-МТС Юрент',
#  'Что делать, если не закрывается замок': 'Развлечения-МТС Юрент',
#  'Замок закрыл, но деньги продолжают списываться': 'Развлечения-МТС Юрент',
#  'Есть только кнопка Ожидание, а завершения аренды нет': 'Развлечения-МТС Юрент',
#  'Не могу завершить аренду на самокате, приложение показывает, что я вне зоны': 'Развлечения-МТС Юрент',
#  'Что делать, если разрядился телефон во время поездки': 'Развлечения-МТС Юрент',
#  'Как арендовать павербанк': 'Развлечения-МТС Юрент',
#  'Как вернуть павербанк': 'Развлечения-МТС Юрент',
#  'Сколько стоит аренда павербанка': 'Развлечения-МТС Юрент',
#  'Как найти зарядную станцию': 'Развлечения-МТС Юрент',
#  'Что можно зарядить, какие разъёмы есть в павербанке': 'Развлечения-МТС Юрент',
#  'Что делать, если павербанк не заряжает или провод не работает': 'Развлечения-МТС Юрент',
#  'Что делать, если станция не принимает павербанк': 'Развлечения-МТС Юрент',
#  'Что делать, если на станции нет свободных ячеек, не могу вернуть павербанк': 'Развлечения-МТС Юрент',
#  'Что делать, если павербанк потерялся': 'Развлечения-МТС Юрент',
#  'Как получить кешбэк за поездки в МТС Юрент': 'Развлечения-МТС Юрент',
#  'Когда начислится кешбэк за поездки в МТС Юрент': 'Развлечения-МТС Юрент',
#  'Как потратить кешбэк в МТС Юрент': 'Развлечения-МТС Юрент',
#  'Почему мне не начислили кешбэк за поездку': 'Развлечения-МТС Юрент',
#  'Для каких платформ можно купить игры': 'Развлечения-Rushbe',
#  'В каких сервисах можно активировать купленные у вас ключи': 'Развлечения-Rushbe',
#  'Как быстро приходит ключ': 'Развлечения-Rushbe',
#  'Что делать, если ключ не приходит': 'Развлечения-Rushbe',
#  'Что делать, если ключ не активируется или пишет, что он уже использован': 'Развлечения-Rushbe',
#  'Сколько раз можно купить одну и ту же игру': 'Развлечения-Rushbe',
#  'На скольких устройствах можно активировать один ключ': 'Развлечения-Rushbe',
#  'Можно ли купить игру в подарок': 'Развлечения-Rushbe',
#  'Можно ли попробовать игру перед покупкой': 'Развлечения-Rushbe',
#  'Можно ли вернуть приобретённую игру': 'Развлечения-Rushbe',
#  'Что такое регион игры и какие они бывают': 'Развлечения-Rushbe',
#  'Что такое предзаказ игры и в чем его преимущества': 'Развлечения-Rushbe',
#  'Можно ли купить DLC отдельно от игры': 'Развлечения-Rushbe',
#  'Что такое DLC и как его купить': 'Развлечения-Rushbe',
#  'Что такое расширенное издание Deluxe/Gold Edition': 'Развлечения-Rushbe',
#  'Что это значит «игра в раннем доступе» и почему за него нужно платить': 'Развлечения-Rushbe',
#  'Как можно оплатить покупку ключа': 'Развлечения-Rushbe',
#  'Как оплатить выбранную игру': 'Развлечения-Rushbe',
#  'Что делать, если в Rushbe не получается оплатить покупку': 'Развлечения-Rushbe',
#  'В какой валюте рассчитывается стоимость ключей': 'Развлечения-Rushbe',
#  'Могу ли я оформить товар в рассрочку или кредит': 'Развлечения-Rushbe',
#  'Какие игры у вас можно купить': 'Развлечения-Rushbe',
#  'Как часто обновляется ваш каталог игр': 'Развлечения-Rushbe',
#  'Как я могу выбрать игру, если не знаю, чего я хочу': 'Развлечения-Rushbe',
#  'Почему на сайте больше нет игры, которую я видел вчера на главной странице': 'Развлечения-Rushbe',
#  'Как узнать можно ли проходить игру вместе с другом на одном телевизоре': 'Развлечения-Rushbe',
#  'Как узнать дату выхода игры': 'Развлечения-Rushbe',
#  'Как зарегистрироваться на Rushbe': 'Развлечения-Rushbe',
#  'Что делать, если не получается зарегистрироваться': 'Развлечения-Rushbe',
#  'Нужно ли мне создавать учётную запись пользователя': 'Развлечения-Rushbe',
#  'Что делать, если смс с кодом для регистрации на Rushbe не приходит': 'Развлечения-Rushbe',
#  'Как активировать ключ в определённом сервисе': 'Развлечения-Rushbe',
#  'Где найти ранее купленные ключи': 'Развлечения-Rushbe',
#  'Как активировать ключ в Steam': 'Развлечения-Rushbe',
#  'Как активировать ключ в Epic Games Store': 'Развлечения-Rushbe',
#  'Как активировать ключ в Ubisoft Connect': 'Развлечения-Rushbe',
#  'Как активировать ключ в VK Play': 'Развлечения-Rushbe',
#  'Что такое МТС Вторая память': 'Утилиты-Вторая Память',
#  'Как начать пользоваться сервисом МТС Вторая память': 'Утилиты-Вторая Память',
#  'Какие есть подписки в МТС Вторая память и сколько они стоят': 'Утилиты-Вторая Память',
#  'Как подключить подписку в МТС Вторая память': 'Утилиты-Вторая Память',
#  'Как отключить МТС Вторая память': 'Утилиты-Вторая Память',
#  'Что будет, если я отключу подписку в МТС Вторая память или перейду на другую': 'Утилиты-Вторая Память',
#  'Что я могу загружать в облако': 'Утилиты-Вторая Память',
#  'Как загрузить файлы, фото и видео в облако': 'Утилиты-Вторая Память',
#  'Как скачать файлы, фото или видео из облака': 'Утилиты-Вторая Память',
#  'Как включить или отключить автозагрузку фото и видео в облако': 'Утилиты-Вторая Память',
#  'Как удалить файлы и что с ними будет после этого': 'Утилиты-Вторая Память',
#  'Как очистить корзину': 'Утилиты-Вторая Память',
#  'Как поделиться ссылкой на файлы, фото или видео': 'Утилиты-Вторая Память',
#  'Как добавить контакты в облако': 'Утилиты-Вторая Память',
#  'Как скачать контакты на телефон': 'Утилиты-Вторая Память',
#  'Как включить или отключить автозагрузку контактов в облако': 'Утилиты-Вторая Память',
#  'Как удалить лишние контакты из облака': 'Утилиты-Вторая Память',
#  'Можно ли перенести контакты во Вторую память из другого облака': 'Утилиты-Вторая Память',
#  'Что такое МТС Лончер': 'Утилиты-МТС Лончер',
#  'Как установить МТС Лончер': 'Утилиты-МТС Лончер',
#  'Как удалить МТС Лончер': 'Утилиты-МТС Лончер',
#  'Как поменять лончер': 'Детям и родителям-МТС Лончер Junior',
#  'Зачем устанавливать МТС Лончер по умолчанию': 'Утилиты-МТС Лончер',
#  'Как убрать рекламу в МТС Лончер': 'Утилиты-МТС Лончер',
#  'Сколько стоит МТС Лончер': 'Утилиты-МТС Лончер',
#  'Трачу ли я интернет, когда использую МТС Лончер': 'Утилиты-МТС Лончер',
#  'Сбой отображения информации в МТС Лончер': 'Утилиты-МТС Лончер',
#  'Приложение МТС Лончер не запускается': 'Утилиты-МТС Лончер',
#  'Проблемы с виджетами': 'Утилиты-МТС Лончер',
#  'Как изменить код для входа в приложение': 'Финансы-МТС Банк',
#  'Как настроить вход в приложение МТС Банка по биометрии': 'Финансы-МТС Банк',
#  'Как подключить пуш-уведомления': 'Финансы-МТС Банк',
#  'Какой статус у моего аккаунта': 'Финансы-МТС Банк',
#  'Как добавить или изменить email': 'Финансы-МТС Банк',
#  'Как изменить номер телефона в МТС Банке': 'Финансы-МТС Банк',
#  'Как перевести деньги по номеру телефона': 'Финансы-МТС Банк',
#  'Как сделать МТС Банк основным для приёма переводов по номеру телефона по СБП': 'Финансы-МТС Банк',
#  'Как оплатить госуслуги, штрафы, налоги': 'Финансы-МТС Банк',
#  'Как оплатить ЖКХ с банковской карты': 'Финансы-МТС Банк',
#  'Как оплатить по QR покупки в магазине': 'Финансы-МТС Банк',
#  'Как перевести деньги по реквизитам': 'Финансы-МТС Банк',
#  'Как настроить шаблон перевода или платежа': 'Финансы-МТС Банк',
#  'Как перевести деньги за границу': 'Финансы-МТС Банк',
#  'Как оформить дебетовую карту': 'Финансы-МТС Банк',
#  'Как оформить кредитную карту': 'Финансы-МТС Банк',
#  'Как заблокировать банковскую карту': 'Финансы-МТС Банк',
#  'Как закрыть банковскую карту': 'Финансы-МТС Банк',
#  'Где можно посмотреть реквизиты карты': 'Финансы-МТС Банк',
#  'Как заказать справки и выписки': 'Финансы-МТС Банк',
#  'Где посмотреть историю операций': 'Финансы-МТС Банк',
#  'Где посмотреть минимальный платеж и долг по кредитной карте': 'Финансы-МТС Банк',
#  'Как установить или изменить PIN-код': 'Финансы-МТС Банк',
#  'Как оформить кредит': 'Финансы-МТС Банк',
#  'Как посмотреть статус заявки на кредит': 'Финансы-МТС Банк',
#  'Можно ли погасить кредит досрочно': 'Финансы-МТС Банк',
#  'Как подключить услуги': 'Финансы-МТС Банк',
#  'Как получить справку или выписку': 'Финансы-МТС Банк',
#  'Как узнать реквизиты для погашения кредита': 'Финансы-МТС Банк',
#  'Как оформить вклад': 'Финансы-МТС Банк',
#  'Как закрыть вклад': 'Финансы-МТС Банк',
#  'Как подключить автоплатёж в МТС Банке': 'Финансы-МТС Банк',
#  'Как отключить автоплатёж в МТС Банке': 'Финансы-МТС Банк',
#  'Может ли автоплатёж подключиться сам': 'Финансы-МТС Банк',
#  'Как изменить дату и сумму автоплатежа в МТС Банке': 'Финансы-МТС Банк',
#  'Как оплатить покупку по QR-коду в приложении МТС Банка': 'Финансы-МТС Банк',
#  'Будет ли кешбэк за оплату по QR-коду': 'Финансы-МТС Банк',
#  'Будет ли комиссия за оплату по QR-коду': 'Финансы-МТС Банк',
#  'Как получить чек об оплате покупки по QR-коду': 'Финансы-МТС Банк',
#  'Какими картами МТС Банка можно оплачивать покупки бесконтактно': 'Финансы-МТС Банк',
#  'Как настроить бесконтактную оплату MIR Pay': 'Финансы-МТС Банк',
#  'Как настроить бесконтактную оплату СБПэй': 'Финансы-МТС Банк',
#  'Как настроить бесконтактную оплату МТС Pay на Android': 'Финансы-МТС Банк',
#  'Как настроить бесконтактную оплату стикером Pay Tag на iPhone': 'Финансы-МТС Банк',
#  'Как получить чек об оплате с банковской карты': 'Финансы-МТС Банк',
#  'Почему не проходит оплата с карты МТС Банка': 'Финансы-МТС Банк',
#  'Как вернуть деньги при ошибочной оплате покупки или услуги': 'Финансы-МТС Банк',
#  'Что делать, если не пришли деньги за возврат покупки, оплаченной стикером Pay Tag': 'Финансы-МТС Банк',
#  'Как перевести деньги с карты на карту по номеру телефона': 'Финансы-МТС Банк',
#  'Как подключить входящие переводы по СБП': 'Финансы-МТС Банк',
#  'Сколько стоит перевод по СБП': 'Финансы-МТС Банк',
#  'Как сделать МТС Банк основным для приёма переводов по СБП': 'Финансы-МТС Банк',
#  'Как отключить входящие переводы по СБП': 'Финансы-МТС Банк',
#  'Как перевести деньги с банковской карты по номеру карты': 'Финансы-МТС Банк',
#  'В какие страны можно перевести деньги': 'Финансы-МТС Банк',
#  'Сколько стоит перевод за границу': 'Финансы-МТС Банк',
#  'Как перевести деньги в Казахстан': 'Финансы-МТС Банк',
#  'Как перевести деньги в Азербайджан': 'Финансы-МТС Банк',
#  'Как перевести деньги в Турцию': 'Финансы-МТС Банк',
#  'Как перевести деньги в Узбекистан': 'Финансы-МТС Банк',
#  'Как перевести деньги в Таджикистан': 'Финансы-МТС Банк',
#  'Как вернуть ошибочный перевод с карты': 'Финансы-МТС Банк',
#  'Не могу перевести деньги с банковской карты': 'Финансы-МТС Банк',
#  'Почему мне не могут перевести по СБП': 'Финансы-МТС Банк',
#  'Почему не могу выбрать другую карту для перевода СБП': 'Финансы-МТС Банк',
#  'Что делать, если перевод не пришёл получателю': 'Финансы-МТС Банк',
#  'Как пополнить дебетовую карту': 'Финансы-МТС Банк',
#  'Как посмотреть историю операций по карте': 'Финансы-МТС Банк',
#  'Как получить выписку по счёту карты': 'Финансы-МТС Банк',
#  'Как узнать реквизиты карты': 'Финансы-МТС Банк',
#  'Как получить справку о доходах для госслужащего': 'Финансы-МТС Банк',
#  'Что делать, если не помню PIN-код карты': 'Финансы-МТС Банк',
#  'Как подключить уведомления об операциях по карте': 'Финансы-МТС Банк',
#  'Как отключить уведомления об операциях по карте': 'Финансы-МТС Банк',
#  'Что делать, если карта потерялась или её украли': 'Финансы-МТС Банк',
#  'Что делать, если мошенники украли деньги с карты': 'Финансы-МТС Банк',
#  'Что делать, если банк заблокировал карту или приложение': 'Финансы-МТС Банк',
#  'Как защитить деньги от мошенников': 'Финансы-МТС Банк',
#  'Как закрыть дебетовую карту': 'Финансы-МТС Банк',
#  'Что делать, если истекает срок действия карты': 'Финансы-МТС Банк',
#  'Как перевыпустить карту': 'Финансы-МТС Банк',
#  'Как погасить долг по кредитной карте': 'Финансы-МТС Банк',
#  'Как узнать минимальный платеж и долг по кредитной карте': 'Финансы-МТС Банк',
#  'Как увеличить кредитный лимит': 'Финансы-МТС Банк',
#  'Как уменьшить кредитный лимит': 'Финансы-МТС Банк',
#  'Как посмотреть историю операций по кредитной карте': 'Финансы-МТС Банк',
#  'Как получить выписку по счёту кредитной карты': 'Финансы-МТС Банк',
#  'Как узнать реквизиты кредитной карты': 'Финансы-МТС Банк',
#  'Как установить или изменить  PIN-код': 'Финансы-МТС Банк',
#  'Как подключить уведомления об операциях по кредитной карте': 'Финансы-МТС Банк',
#  'Как отключить уведомления об операциях по кредитной карте': 'Финансы-МТС Банк',
#  'Что делать, если кредитная карта потерялась или её  украли': 'Финансы-МТС Банк',
#  'Что делать, если мошенники украли деньги с кредитной карты': 'Финансы-МТС Банк',
#  'Что делать, если банк заблокировал кредитную карту или приложение': 'Финансы-МТС Банк',
#  'Что делать, если истекает срок действия кредитной карты': 'Финансы-МТС Банк',
#  'Как перевыпустить кредитную карту': 'Финансы-МТС Банк',
#  'Как закрыть кредитную карту': 'Финансы-МТС Банк',
#  'Как проверить информацию по своему кредиту': 'Финансы-МТС Банк',
#  'Где посмотреть договор на кредит': 'Финансы-МТС Банк',
#  'Как узнать плановый платеж, посмотреть график': 'Финансы-МТС Банк',
#  'Как получить справку о закрытии и другие документы по кредиту': 'Финансы-МТС Банк',
#  'Как продлить полис по ипотеке': 'Финансы-МТС Банк',
#  'Платите за кредит без комиссий': 'Финансы-МТС Банк',
#  'Оформите рассрочку': 'Финансы-МТС Банк',
#  'Погашайте кредит досрочно': 'Финансы-МТС Банк',
#  'Сокращайте срок кредита или платеж': 'Финансы-МТС Банк',
#  'Объедините несколько кредитов в один': 'Финансы-МТС Банк',
#  'Как пропустить платеж или изменить его дату': 'Финансы-МТС Банк',
#  'Как взять «каникулы» на оплату кредита': 'Финансы-МТС Банк',
#  'Как оформить виртуальную дебетовую карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как оформить пластиковую дебетовую карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как оформить виртуальную кредитную карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как оформить пластиковую кредитную карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как перевыпустить банковскую карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как пополнить виртуальную дебетовую карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как пополнить пластиковую дебетовую карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как пополнить кредитную карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как установить или изменить PIN-код по дебетовой карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Как установить или изменить PIN-код по кредитной карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Что делать, если не помню PIN-код по карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Как посмотреть реквизиты карты МТС Деньги': 'Финансы-МТС Деньги',
#  'Как получить справку по карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Как посмотреть историю операций по карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Как получить выписку по карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Какие лимиты на покупки и снятие наличных по карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Сколько всего денег можно держать на карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Как подключить уведомления об операциях по карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Как отключить уведомления об операциях по карте МТС Деньги': 'Финансы-МТС Деньги',
#  'Можно ли снимать и переводить деньги с карты МТС Деньги': 'Финансы-МТС Деньги',
#  'Как платить картой МТС Деньги бесконтактно с телефона': 'Финансы-МТС Деньги',
#  'При оплате онлайн требуется ввести ФИО, а их нет на карте': 'Финансы-МТС Деньги',
#  'Что такое кешбэк': 'Финансы-МТС Деньги',
#  'За что начисляется кешбэк': 'Финансы-МТС Деньги',
#  'За что кешбэк не начисляется': 'Финансы-МТС Деньги',
#  'Как выбрать категории кешбэка': 'Финансы-МТС Деньги',
#  'Как узнать, сколько кешбэка начислили за покупку': 'Финансы-МТС Деньги',
#  'Какой максимальный кешбэк можно получить': 'Финансы-МТС Деньги',
#  'Когда начисляется кешбэк': 'Финансы-МТС Деньги',
#  'На что потратить кешбэк': 'Финансы-МТС Деньги',
#  'Почему мне не пришёл кешбэк': 'Финансы-МТС Деньги',
#  'Что делать, если карта МТС Деньги потерялась или её украли': 'Финансы-МТС Деньги',
#  'Как закрыть банковскую карту МТС Деньги': 'Финансы-МТС Деньги',
#  'Как войти в приложение МТС Деньги': 'Финансы-МТС Деньги',
#  'Как изменить код для входа в приложение МТС Деньги': 'Финансы-МТС Деньги',
#  'Как настроить биометрию в приложении МТС Деньги': 'Финансы-МТС Деньги',
#  'Что такое МТС Все страховки': 'Финансы-МТС Все страховки',
#  'Где найти полис после покупки': 'Финансы-МТС Все страховки',
#  'Как оформить полис страхования от мошенников': 'Финансы-МТС Все страховки',
#  'Сколько стоит полис страхования от мошенников': 'Финансы-МТС Все страховки',
#  'Какие риски покрывает страхование от мошенников': 'Финансы-МТС Все страховки',
#  'Какие карты можно застраховать': 'Финансы-МТС Все страховки',
#  'Когда начнёт действовать полис страхования от мошенников': 'Финансы-МТС Все страховки',
#  'Какие лимиты по выплатам при страховании от мошенников': 'Финансы-МТС Все страховки',
#  'Страховой случай по мошенничеству на сумму более 50 000 ₽': 'Финансы-МТС Все страховки',
#  'Страховой случай по мошенничеству на сумму менее 50 000 ₽': 'Финансы-МТС Все страховки',
#  'Страхование от мошенников в подписке МТС Premium': 'Финансы-МТС Все страховки',
#  'Какие документы нужны для оформления ОСАГО?': 'Финансы-МТС Все страховки',
#  'Как проверить подлинность полиса ОСАГО': 'Финансы-МТС Все страховки',
#  'Нужно ли распечатывать электронный полис ОСАГО?': 'Финансы-МТС Все страховки',
#  'На какой срок можно оформить полис ОСАГО?': 'Финансы-МТС Все страховки',
#  'Что такое коэффициент бонус-малус (КБМ)?': 'Финансы-МТС Все страховки',
#  'Как узнать свой КБМ?': 'Финансы-МТС Все страховки',
#  'Когда нужно продлевать ОСАГО?': 'Финансы-МТС Все страховки',
#  'Как продлить полис ОСАГО?': 'Финансы-МТС Все страховки',
#  'Какие документы нужны для продления полиса ОСАГО?': 'Финансы-МТС Все страховки',
#  'На какой тип транспортного средства можно оформить?': 'Финансы-МТС Все страховки',
#  'Можно ли оформить полис без ограничения количества водителей?': 'Финансы-МТС Все страховки',
#  'Какое водительское удостоверение подойдет для оформления страхового полиса?': 'Финансы-МТС Все страховки',
#  'Можно ли внести изменения в электронный полис ОСАГО?': 'Финансы-МТС Все страховки',
#  'Можно ли расторгнуть полис ОСАГО?': 'Финансы-МТС Все страховки',
#  'Для чего нужно КАСКО?': 'Финансы-МТС Все страховки',
#  'В чем различие между ОСАГО и КАСКО?': 'Финансы-МТС Все страховки',
#  'Что покрывает КАСКО': 'Финансы-МТС Все страховки',
#  'На какой срок можно оформить полис КАСКО?': 'Финансы-МТС Все страховки',
#  'На какой тип автомобиля можно оформить страхование КАСКО?': 'Финансы-МТС Все страховки',
#  'Страхование для путешествий это?': 'Финансы-МТС Все страховки',
#  'Когда начнёт действовать полис страхования для путешествий?': 'Финансы-МТС Все страховки',
#  'На какие случаи полис страхования для путешествий не распространяется?': 'Финансы-МТС Все страховки',
#  'Что делать при страховом случае?': 'Финансы-МТС Все страховки',
#  'Можно ли оформить полис, находясь в поездке?': 'Финансы-МТС Все страховки',
#  'Как выбрать тип отдыха?': 'Финансы-МТС Все страховки',
#  'Как получить возмещение': 'Финансы-МТС Все страховки',
#  'Что делать если моя поездка будет больше 60 дней': 'Финансы-МТС Все страховки',
#  'Спорт включён в сертификат': 'Финансы-МТС Все страховки',
#  'На какие случаи полис страхования путешествий не распространяется': 'Финансы-МТС Все страховки',
#  'Что делать при наступлении страхового случая в путешествии': 'Финансы-МТС Все страховки',
#  'Как подать документы при страховом случае': 'Финансы-МТС Все страховки',
#  'Какие документы необходимо подать при страховом случае': 'Финансы-МТС Все страховки',
#  'Какие документы нужны для покупки полиса?': 'Финансы-МТС Все страховки',
#  'Где можно найти чек после покупки полиса?': 'Финансы-МТС Все страховки',
#  'Текущий полис закончится только в следующем месяце. Могу ли я уже приобрести новый?': 'Финансы-МТС Все страховки',
#  'Как узнать, допущена ли Страховая компания к страхованию ипотечных договоров моего банка?': 'Финансы-МТС Все страховки',
#  'Сколько действует договор ипотечного страхования?': 'Финансы-МТС Все страховки',
#  'Зачем страховать здоровье и жизнь заемщика?': 'Финансы-МТС Все страховки',
#  'Сколько стоит страхование квартиры при ипотеке?': 'Финансы-МТС Все страховки',
#  'Как рассчитать стоимость ипотечного страхования жизни?': 'Финансы-МТС Все страховки',
#  'Где можно узнать дату окончания ипотеки?': 'Финансы-МТС Все страховки',
#  'Где найти чек после покупки': 'Финансы-МТС Все страховки',
#  'Как проверить, что Страховая компания допущена к страхованию ипотечных договоров моего банка': 'Финансы-МТС Все страховки',
#  'У меня частный дом. Могу ли я оформить полис по страхованию имущества': 'Финансы-МТС Все страховки',
#  'Текущий полис закончится только в следующем месяце. Доступно ли мне предложение': 'Финансы-МТС Все страховки',
#  'Нужно ли относить купленный полис страхования в отделение банка': 'Финансы-МТС Все страховки',
#  'Какой срок действия у договора ипотечного страхования?': 'Финансы-МТС Все страховки',
#  'Повысится ли процентная ставка по ипотеке, если продлить страхование у нас': 'Финансы-МТС Все страховки',
#  'Как узнать сумму остатка задолженности в СберБанке?': 'Финансы-МТС Все страховки',
#  'Как узнать номер ипотечного договора СберБанка и дату его заключения': 'Финансы-МТС Все страховки',
#  'Где найти чек после покупки полиса': 'Финансы-МТС Все страховки',
#  'Я являюсь собственником частного дома. Могу ли оформить полис страхования имущества': 'Финансы-МТС Все страховки',
#  'Текущий полис еще действует. Доступно ли мне предложение': 'Финансы-МТС Все страховки',
#  'Как проверить, что Ренессанс страхование допущен к страхованию ипотечных договоров ВТБ Банк': 'Финансы-МТС Все страховки',
#  'Нужно ли относить купленный полис в отделение ВТБ Банка': 'Финансы-МТС Все страховки',
#  'Какой срок действия полиса ипотечного страхования': 'Финансы-МТС Все страховки',
#  'Может ли повыситься процентная ставка по ипотеке, если продлить страхование жизни у нас': 'Финансы-МТС Все страховки',
#  'Как узнать сумму остатка задолженности': 'Финансы-МТС Все страховки',
#  'Как узнать номер договора и дату его заключения': 'Финансы-МТС Все страховки',
#  'Как узнать свою процентную ставку по ипотеке': 'Финансы-МТС Все страховки',
#  'Как узнать размер ежемесячного платежа по ипотеке': 'Финансы-МТС Все страховки',
#  'Где найти чек после покупки полиса страхования': 'Финансы-МТС Все страховки',
#  'У меня частный дом. Могу ли оформить полис по страхованию имущества': 'Финансы-МТС Все страховки',
#  'Текущий полис страхования закончится только в следующем месяце. Доступно ли мне предложение': 'Финансы-МТС Все страховки',
#  'Как проверить, что Ренессанс страхование допущен к страхованию ипотечных договоров МКБ': 'Финансы-МТС Все страховки',
#  'Нужно ли относить купленный полис в отделение банка': 'Финансы-МТС Все страховки',
#  'Какой срок действия договора страхования ипотеки': 'Финансы-МТС Все страховки',
# ...
#  'Ренессанс': 'Финансы-МТС Все страховки',
#  'Росгосстрах': 'Финансы-МТС Все страховки',
#  'АльфаСтрахование': 'Финансы-МТС Все страховки',
#  'ВСК': 'Финансы-МТС Все страховки',
#  'Ингосстрах': 'Финансы-МТС Все страховки',
#  'Тинькофф': 'Финансы-МТС Все страховки',
#  'Сбер Страхование': 'Финансы-МТС Все страховки',
#  'Согласие': 'Финансы-МТС Все страховки',
#  'Zetta': 'Финансы-МТС Все страховки',
#  'INTOUCH': 'Финансы-МТС Все страховки',
#  'Энергогарант': 'Финансы-МТС Все страховки',
#  'Ренессанс Страхование КАСКО': 'Финансы-МТС Все страховки',
#  'СберСтрахование': 'Финансы-МТС Все страховки',
#  'Ренессанс страхование': 'Финансы-МТС Все страховки',
#  'Что делать, если в поездке потребовалась медицинская помощь': 'Финансы-МТС Все страховки',
#  'Как возместить понесённые в путешествии расходы': 'Финансы-МТС Все страховки',
#  'Какие документы нужны для заявления о страховом случае': 'Финансы-МТС Все страховки',
#  'Как сообщить о страховом случае': 'Финансы-МТС Все страховки',
#  'Где найти страховой сертификат': 'Финансы-МТС Все страховки',
#  'Когда начнёт действовать страховой сертификат': 'Финансы-МТС Все страховки',
#  'На какой срок даётся сертификат': 'Финансы-МТС Все страховки',
#  'Какой случай считать страховым': 'Финансы-МТС Все страховки',
#  'Что не попадает под страховой случай': 'Финансы-МТС Все страховки',
#  'Что делать, если наступил страховой случай': 'Финансы-МТС Все страховки',
#  'Как расторгнуть договор страхования': 'Финансы-МТС Все страховки',
#  'С чего начать': 'Финансы-МТС Инвестиции',
#  'Общая информация': 'Финансы-МТС Инвестиции',
#  'Открытие брокерского счёта': 'Финансы-МТС Инвестиции',
#  'Пополнение брокерского счёта': 'Финансы-МТС Инвестиции',
#  'Вывод денег, закрытие брокерского счета': 'Финансы-МТС Инвестиции',
#  'Ценные бумаги и операции с ними': 'Финансы-МТС Инвестиции',
#  'Срочный рынок': 'Финансы-МТС Инвестиции',
#  'Биржевые паевые инвестиционные фонды (БПИФы)': 'Финансы-МТС Инвестиции',
#  'Операции с ПИФами': 'Финансы-МТС Инвестиции',
#  'Налоговый вычет по ИИС': 'Финансы-МТС Инвестиции',
#  'Как погасить паи фондов': 'Финансы-МТС Инвестиции',
#  'Как и когда выплачиваются деньги': 'Финансы-МТС Инвестиции',
#  'Как я могу узнать о выплате денег': 'Финансы-МТС Инвестиции',
#  'Как получить деньги от погашения паев': 'Финансы-МТС Инвестиции',
#  'Что делать, если реквизиты банковского счёта для получения выплаты не указаны': 'Финансы-МТС Инвестиции',
#  'Можно ли купить паи фондов через управляющую компанию': 'Финансы-МТС Инвестиции',
#  'Можно ли обменять паи фондов «Биотехнологии» и «Высокие технологии» на паи других фондов': 'Финансы-МТС Инвестиции',
#  'Есть ли налог на сумму, которую я получаю при погашении паев': 'Финансы-МТС Инвестиции',
#  'Как часто выплачивают деньги владельцам инвестиционных паев': 'Финансы-МТС Инвестиции',
#  'Как быстро перечисляются деньги при погашении паев': 'Финансы-МТС Инвестиции',
#  'Почему изменилась сумма моих активов': 'Финансы-МТС Инвестиции',
#  'По какой стоимости оцениваются активы': 'Финансы-МТС Инвестиции',
#  'Что будет с активами': 'Финансы-МТС Инвестиции',
#  'Как часто обновляется стоимость в фондах': 'Финансы-МТС Инвестиции',
#  'Как передать управляющей компании новые реквизиты моего счёта или иные данные': 'Финансы-МТС Инвестиции',
#  'Как мне изменить анкетные данные, например, номер телефона или фамилию, если у меня куплены паи открытых паевых инвестиционных фондов': 'Финансы-МТС Инвестиции',
#  'Как мне изменить анкетные данные, например, номер телефона или фамилию, если у меня ДУ ИИС': 'Финансы-МТС Инвестиции',
#  'Как мне изменить анкетные данные, например, номер телефона или фамилию, если у меня открыт брокерский счет': 'Финансы-МТС Инвестиции',
#  'Почему БПИФ «Информатика+» стал закрытым': 'Финансы-МТС Инвестиции',
#  'Когда возобновятся торги инвестиционными паями на Московской Бирже': 'Финансы-МТС Инвестиции',
#  'Когда погасят паи': 'Финансы-МТС Инвестиции',
#  'Как мне получить деньги при погашении паев': 'Финансы-МТС Инвестиции',
#  'Почему перестала отображаться позиция по паям на моём биржевом счёте': 'Финансы-МТС Инвестиции',
#  'Что такое МТС Лончер Junior': 'Детям и родителям-МТС Лончер Junior',
#  'Как установить МТС Лончер Junior': 'Детям и родителям-МТС Лончер Junior',
#  'Как удалить МТС Лончер Junior': 'Детям и родителям-МТС Лончер Junior',
#  'Зачем устанавливать МТС Лончер Junior по умолчанию': 'Детям и родителям-МТС Лончер Junior',
#  'Сколько стоит МТС Лончер Junior': 'Детям и родителям-МТС Лончер Junior',
#  'Трачу ли я интернет, когда использую МТС Лончер Junior': 'Детям и родителям-МТС Лончер Junior',
#  'Сбой отображения информации в МТС Лончер Junior': 'Детям и родителям-МТС Лончер Junior',
#  'Приложение МТС Лончер Junior не запускается': 'Детям и родителям-МТС Лончер Junior',
#  'Проблемы с виджетами в МТС Лончер Junior': 'Детям и родителям-МТС Лончер Junior',
#  'Что такое МТС Junior': 'Детям и родителям-МТС Junior',
#  'Как стать участником МТС Junior': 'Детям и родителям-МТС Junior',
#  'Какие привилегии входят в МТС Junior': 'Детям и родителям-МТС Junior',
#  'Сколько стоит подписка МТС Junior': 'Детям и родителям-МТС Junior',
#  'Почему больше недоступны привилегии МТС Junior': 'Детям и родителям-МТС Junior',
#  'Как управлять подпиской МТС Junior': 'Детям и родителям-МТС Junior',
#  'Как отказаться от подписки МТС Junior': 'Детям и родителям-МТС Junior',
#  'Как начать пользоваться привилегиями МТС Junior': 'Детям и родителям-МТС Junior',
#  'Как воспользоваться сервисом Где мои дети': 'Детям и родителям-МТС Junior',
#  'Как ребёнку воспользоваться KION с детским профилем': 'Детям и родителям-МТС Junior',
#  'Как ребёнку воспользоваться МТС Музыкой с детским режимом': 'Детям и родителям-МТС Junior',
#  'Как родителю отследить процесс обучения в ЛогикЛайк': 'Детям и родителям-МТС Junior',
#  'Как ребёнку воспользоваться безлимитными соц.сетями и Likee': 'Детям и родителям-МТС Junior',
#  'Как ребёнку воспользоваться Защитником': 'Детям и родителям-МТС Junior',
#  'Как воспользоваться группой услуг Безопасность расходов': 'Детям и родителям-МТС Junior',
#  'Что делать, если я подключил подписку МТС Junior на другой номер': 'Детям и родителям-МТС Junior',
#  'Как поменять возраст контента и ПИН-код в KION у ребёнка с подпиской МТС Junior': 'Детям и родителям-МТС Junior',
#  'Как отключить детский профиль в KION и МТС Музыке': 'Детям и родителям-МТС Junior',
#  'Как ребёнку пользоваться сервисом ЛогикЛайк': 'Детям и родителям-МТС Junior',
#  'Что такое Membrana Kids': 'Детям и родителям-Membrana Kids',
#  'Сколько стоит услуга': 'Детям и родителям-Membrana Kids',
#  'Сколько детей можно подключить к аккаунту родителя': 'Детям и родителям-Membrana Kids',
#  'Как начать пользоваться сервисом Membrana Kids': 'Детям и родителям-Membrana Kids',
#  'Как подключить ребёнка в Membrana Kids': 'Детям и родителям-Membrana Kids',
#  'Как заполнить профиль ребёнка': 'Детям и родителям-Membrana Kids',
#  'Как отключить услугу с номера ребёнка': 'Детям и родителям-Membrana Kids',
#  'Как удалить профиль ребёнка в Membrana Kids': 'Детям и родителям-Membrana Kids',
#  'Как посмотреть, какие сайты посещал мой ребёнок': 'Детям и родителям-Membrana Kids',
#  'Описание режимов доступа к интернет-ресурсам': 'Детям и родителям-Membrana Kids',
#  'Как настроить ручной режим': 'Детям и родителям-Membrana Kids',
#  'Как ограничить время доступа к интернету': 'Детям и родителям-Membrana Kids',
#  'Как отключить ограничение доступа к интернет-ресурсам': 'Детям и родителям-Membrana Kids',
#  'Как настроить сертификат в Membrana Kids': 'Детям и родителям-Membrana Kids',
#  'Описание режимов голосовой фильтрации': 'Детям и родителям-Membrana Kids',
#  'Как настроить доверенный список': 'Детям и родителям-Membrana Kids',
#  'Как настроить DNS-сервер для работы Membrana Kids при подключении к сети Wi-Fi': 'Детям и родителям-Membrana Kids',
#  'Не могу установить приложение Membrana Kids': 'Детям и родителям-Membrana Kids',
#  'Membrana Kids некорректно работает': 'Детям и родителям-Membrana Kids',
#  'Как установить приложение МТС Умный дом': 'Для дома-МТС Умный дом',
#  'Как войти в аккаунт приложения МТС Умный дом': 'Для дома-МТС Умный дом',
#  'Как настроить сценарий для работы умных устройств': 'Для дома-МТС Умный дом',
#  'Что такое Домашний центр МТС': 'Для дома-МТС Умный дом',
#  'Как добавить Домашний центр МТС с функциями роутера': 'Для дома-МТС Умный дом',
#  'Как добавить Домашний центр МТС без функций роутера': 'Для дома-МТС Умный дом',
#  'Что делать, если не получается добавить умное устройство': 'Для дома-МТС Умный дом',
#  'Как работает умный датчик открытия дверей и окон': 'Для дома-МТС Умный дом',
#  'Как установить умный датчик открытия дверей и окон': 'Для дома-МТС Умный дом',
#  'Как добавить умный датчик открытия дверей и окон': 'Для дома-МТС Умный дом',
#  'Как работает умная лампа': 'Для дома-МТС Умный дом',
#  'Как установить умную лампу': 'Для дома-МТС Умный дом',
#  'Как добавить умную лампу': 'Для дома-МТС Умный дом',
#  'Как работает умная розетка': 'Для дома-МТС Умный дом',
#  'Как установить умную розетку': 'Для дома-МТС Умный дом',
#  'Как добавить умную розетку': 'Для дома-МТС Умный дом',
#  'Световая индикация умной розетки': 'Для дома-МТС Умный дом',
#  'Как работает умный датчик дыма': 'Для дома-МТС Умный дом',
#  'Как установить умный датчик дыма': 'Для дома-МТС Умный дом',
#  'Как добавить умный датчик дыма': 'Для дома-МТС Умный дом',
#  'Индикация умного датчика дыма': 'Для дома-МТС Умный дом',
#  'Как заменить батарею у умного датчика дыма': 'Для дома-МТС Умный дом',
#  'Как устранить неполадки в работе умного датчика дыма': 'Для дома-МТС Умный дом',
#  'Как работает умный датчик температуры и влажности воздуха': 'Для дома-МТС Умный дом',
#  'Как установить умный датчик температуры и влажности': 'Для дома-МТС Умный дом',
#  'Как добавить умный датчик температуры и влажности воздуха': 'Для дома-МТС Умный дом',
#  'Как заменить батарею у умного датчика температуры и влажности воздуха': 'Для дома-МТС Умный дом',
#  'Как работает умный датчик протечки': 'Для дома-МТС Умный дом',
#  'Как установить умный датчик протечки': 'Для дома-МТС Умный дом',
#  'Как добавить умный датчик протечки': 'Для дома-МТС Умный дом',
#  'Как заменить батарею в умном датчике протечки': 'Для дома-МТС Умный дом',
#  'Как добавить умную домашнюю камеру': 'Для дома-МТС Умный дом',
#  'Как изменить настройки умной домашней камеры': 'Для дома-МТС Умный дом',
#  'Как включить и выключить обнаружение и фиксацию событий': 'Для дома-МТС Умный дом',
#  'Как скачать видео из видеоархива': 'Для дома-МТС Умный дом',
#  'Сколько хранятся видеозаписи': 'Для дома-МТС Умный дом',
#  'Что такое история событий': 'Для дома-МТС Умный дом',
#  'Характеристики камеры': 'Для дома-МТС Умный дом',
#  'Остальные вопросы об умной домашней камере': 'Для дома-МТС Умный дом',
#  'Что делать, если не работает умная домашняя камера': 'Для дома-МТС Умный дом',
#  'Как работает умный увлажнитель': 'Для дома-МТС Умный дом',
#  'Как подключить умный увлажнитель': 'Для дома-МТС Умный дом',
#  'Как добавить умный увлажнитель': 'Для дома-МТС Умный дом',
#  'Как ухаживать за умным увлажнителем': 'Для дома-МТС Умный дом',
#  'Как устранить неисправности в работе умного увлажнителя': 'Для дома-МТС Умный дом',
#  'Как работает умный кондиционер': 'Для дома-МТС Умный дом',
#  'Как установить умный кондиционер': 'Для дома-МТС Умный дом',
#  'Как добавить умный кондиционер': 'Для дома-МТС Умный дом',
#  'Допустимые температурные значения': 'Для дома-МТС Умный дом',
#  'Гарантия изготовителя на умные устройства': 'Для дома-МТС Умный дом',
#  'Условия предоставления гарантии на умные устройства': 'Для дома-МТС Умный дом',
#  'Как устранить неполадки в работе умных устройств': 'Для дома-МТС Умный дом',
#  'Как удалить аккаунт в приложении МТС Умный дом': 'Для дома-МТС Умный дом',
#  'Как удалить устройство в приложении МТС Умный дом': 'Для дома-МТС Умный дом',
#  'Как установить приложение VDome': 'Для дома-VDome',
#  'Как войти в аккаунт VDome': 'Для дома-VDome',
#  'Как добавить дополнительного пользователя': 'Для дома-VDome',
#  'Как узнать, какая организация обслуживает домофон по моему адресу': 'Для дома-VDome',
#  'Как удалить аккаунт VDome': 'Для дома-VDome',
#  'Как принять вызов с домофона': 'Для дома-VDome',
#  'Как открыть дверь домофона': 'Для дома-VDome',
#  'Как посмотреть историю событий домофона': 'Для дома-VDome',
#  'Как добавить камеру в приложении VDome': 'Для дома-VDome',
#  'Как посмотреть видео с камеры': 'Для дома-VDome',
#  'Как просмотреть видео с архива камеры': 'Для дома-VDome',
#  'Как принять вызов, если нет приложения или интернета': 'Для дома-VDome',
#  'Как разблокировать услугу': 'Для дома-VDome',
#  'Как создать заявку в Домофонную компанию': 'Для дома-VDome',
#  'Почему вызовы могут не поступать в приложение': 'Для дома-VDome',
#  'Что делать, если не получается добавить пользователя': 'Для дома-VDome',
#  'Что делать, если приложение VDome не работает': 'Для дома-VDome',
#  'Как оформить заказ в интернет-магазине МТС': 'Другое-Интернет-магазин',
#  'Как отследить заказ из интернет-магазина МТС': 'Другое-Интернет-магазин',
#  'Как получить заказ из интернет-магазина МТС': 'Другое-Интернет-магазин',
#  'Как изменить заказ из интернет-магазина МТС': 'Другое-Интернет-магазин',
#  'Как узнать номер заказа в интернет-магазине МТС': 'Другое-Интернет-магазин',
#  'Как отменить заказ из интернет-магазина МТС': 'Другое-Интернет-магазин',
#  'Сколько стоит доставка': 'Другое-Интернет-магазин',
#  'Может ли другой человек получить доставку': 'Другое-Интернет-магазин',
#  'Как перенести время доставки или изменить адрес': 'Другое-Интернет-магазин',
#  'Сколько хранится заказ в салоне экосистемы МТС': 'Другое-Интернет-магазин',
#  'Как продлить срок хранения заказа в магазине': 'Другое-Интернет-магазин',
#  'Как оплатить заказ в интернет-магазине МТС': 'Другое-Интернет-магазин',
#  'Как купить товар в рассрочку в интернет-магазине МТС': 'Другое-Интернет-магазин',
#  'Как зайти в Личный кабинет интернет-магазина МТС и что в нём доступно': 'Другое-Интернет-магазин',
#  'Как вернуть товар без брака': 'Другое-Интернет-магазин',
#  'Как вернуть товар по гарантии': 'Другое-Интернет-магазин',
#  'Как узнать статус ремонта или проверки качества товара': 'Другое-Интернет-магазин',
#  'Как получить кешбэк за покупку в интернет-магазине МТС': 'Другое-Интернет-магазин',
#  'Когда начислится кешбэк за покупку в интернет-магазине МТС': 'Другое-Интернет-магазин',
#  'Что такое МТС Тестирование': 'Другое-МТС Тестирование',
#  'Сколько длится тестирование': 'Другое-МТС Тестирование',
#  'Как узнать про новые тестирования': 'Другое-МТС Тестирование',
#  'Что я получу за тестирование': 'Другое-МТС Тестирование',
#  'Что такое закрытое тестирование': 'Другое-МТС Тестирование',
#  'Что нужно знать, чтобы тестировать продукты': 'Другое-МТС Тестирование',
#  'Какое нужно оборудование для тестирования': 'Другое-МТС Тестирование',
#  'Что такое альфа-тестирование и как его начать': 'Другое-МТС Тестирование',
#  'Что такое бета-тестирование и как его начать': 'Другое-МТС Тестирование',
#  'Не получается закончить регистрацию: email уже существует': 'Другое-МТС Тестирование',
#  'Что конкретно нужно проверять при тестировании': 'Другое-МТС Тестирование',
#  'Где и как объявят результаты тестирования': 'Другое-МТС Тестирование',
#  'Как сообщить об ошибке, найденной вне тестирования': 'Другое-МТС Тестирование',
#  'Куда обращаться, если есть вопросы по тестируемому продукту': 'Другое-МТС Тестирование',
#  'Почему нет продуктов на тестировании': 'Другое-МТС Тестирование',
#  'В профиле нет моего устройства или версии операционной системы': 'Другое-МТС Тестирование',
#  'В профиле нет моего рода занятий': 'Другое-МТС Тестирование',
#  'Как изменить номер телефона в профиле МТС Тестирование': 'Другое-МТС Тестирование',
#  'Как изменить email в профиле МТС Тестирование': 'Другое-МТС Тестирование',
#  'Что такое Crowdloud': 'Другое-Crowdloud',
#  'Какие функции выполняет платформа Crowdloud': 'Другое-Crowdloud',
#  'Как пользоваться платформой Crowdloud потенциальным участникам': 'Другое-Crowdloud',
#  'Кто может участвовать в проектах на платформе': 'Другое-Crowdloud',
#  'Что происходит, когда вы поддержали проект': 'Другое-Crowdloud',
#  'Что будет, если проект в указанный срок не привлечёт необходимую для финансирования сумму': 'Другое-Crowdloud'}

# %%
query = 'Чтобы проверить баланс и пакеты по тарифу:\n\n1. **В приложении "Мой МТС":**\n   - На главной странице нажмите на название вашего тарифа.\n   - Откроется экран с информацией о размере и остатках пакетов интернета, минут и SMS.\n   - Нажмите на "Настроить" (для тарифов с пакетами) или "О тарифе" для полного описания.\n\n2. **В Личном кабинете:**\n   - Проверьте подаренные минуты и уточните абонентскую плату.\n\nТакже можно использовать виджеты приложения для уточнения абонентской платы и баланса.'
result = retrieve_similar_entry(query)
if result:
    print(f"Most similar entry: {answer_dict[result['original_text']]}")
    print(f"Confidence (cosine similarity): {result['confidence']}")
else:
    print("No similar entries found.")
# Out:
# Most similar entry: Главное-Приложение Мой МТС
# Confidence (cosine similarity): 0.8087646961212158
# Original series index: 3
